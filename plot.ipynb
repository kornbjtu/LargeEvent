# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd


d = pd.read_csv("output.csv")

# %%
d.describe()
# Out:
#          total_cons  standby_cons  ave_waiting_time       mileage  \
# count  43200.000000  43200.000000      43200.000000  43200.000000
# mean     320.263514     13.811122       2348.179562    681.256079
# std      201.965114      8.731803        601.685715    409.832539
# min        0.000000      0.000000          0.000000      0.000000
# 25%      142.452492      6.595334       2462.457146    332.942858
# 50%      312.770043     13.937659       2505.896551    700.341038
# 75%      502.441813     20.693047       2520.643767   1020.759930
# max      659.692191     30.191569       2876.613139   1388.691008
#
#           mean_time  truck_in_depot_0  truck_in_depot_1  truck_in_depot_2  \
# count  43200.000000      43200.000000      43200.000000      43200.000000
# mean   21599.500000          4.167801          3.919074          3.400972
# std    12470.910151          0.858014          0.931471          0.872458
# min        0.000000          2.000000          2.000000          1.000000
# ...

# %%
d[["total_cons"]].plot()
# Out:
# <Axes: >
