# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
plt.style.use('default')
plt.figure(figsize=(10, 20))

d = pd.read_csv("output/output.csv")

# %%
d.describe()
# Out:
#          total_cons  standby_cons  ave_waiting_time       mileage  \
# count  43200.000000  43200.000000      43200.000000  43200.000000
# mean     361.107840     16.428153       1994.717922    982.482272
# std      236.864087     10.238987        469.916169    607.625322
# min        0.000000      0.000000          0.000000      0.000000
# 25%      141.738727      6.595334       2069.941394    442.295593
# 50%      336.768519     17.222819       2093.678134    963.590682
# 75%      599.665330     26.299834       2144.624921   1565.771652
# max      682.737981     29.414355       2231.305135   1814.539315
#
#           mean_time  truck_in_depot_0  truck_in_depot_1  truck_in_depot_2  \
# count  43200.000000      43200.000000      43200.000000      43200.000000
# mean   21599.500000          4.499005          4.275278          3.770023
# std    12470.910151          0.834952          0.749552          0.731448
# min        0.000000          3.000000          2.000000          2.000000
# ...

# %%
d.columns
# Out:
# Index(['total_cons', 'standby_cons', 'ave_waiting_time', 'mileage',
#        'mean_time', 'truck_in_depot_0', 'truck_in_depot_1', 'truck_in_depot_2',
#        'truck_in_depot_3', 'carbon_emission', 'order_number', 'ave_queue_time',
#        'total_queue_length', 'service_cons', 'time_window_ave_queue_time',
#        'time_window_ave_waiting_time', 'truck_total_time_parking',
#        'truck_total_time_queue', 'truck_total_time_service',
#        'truck_total_time_delivery', 'time_window_truck_total_time_parking',
#        'time_window_truck_total_time_queue',
#        'time_window_truck_total_time_service',
#        'time_window_truck_total_time_delivery', 'completed_order_num',
#        'unfinished_order_0', 'unfinished_order_1', 'unfinished_order_2',
#        'unfinished_order_3'],
#       dtype='object')

# %%
d[['completed_order_num']].max()
# Out:
# completed_order_num    349
# dtype: int64

# %%
# Plotting the data
plt.figure(figsize=(15, 7))
d[['unfinished_order_0', 'unfinished_order_1', 'unfinished_order_2', 'unfinished_order_3']][0:2500].plot(ax=plt.gca(), linewidth=2)

# Adding vertical lines with increased thickness
plt.axvline(x=600, color="b", linewidth=1, linestyle='--')
plt.axvline(x=1200, color="r", linewidth=1, linestyle='--')

plt.xlabel('Time (second)', fontsize=16)
plt.ylabel('Number of Order', fontsize=16)
plt.title('Unfinished Orders', fontsize=18)
plt.legend(["Depot0", "Depot1", "Depot2", "Depot3"], fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.grid()
# Show the plot
plt.show()

# %%
# Sample data creation (this would be replaced by the actual DataFrame 'd' in your context)
# Sample data for demonstration

# Plotting the data
plt.figure(figsize=(15, 7))
d[['order_number']][:10000].plot(ax=plt.gca(), linewidth=2)

# Setting larger font size for text and ticks
plt.xlabel('Time (second)', fontsize=14)
plt.ylabel('Generated number of order', fontsize=14)
plt.title('The number of generated order change over time', fontsize=18)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Marking a specific point
x_point = 10000
y_point = d['order_number'][x_point]

# Annotate the point
plt.annotate(f'(time={round(x_point / 60,2)} min, order={y_point:.2f})', 
             xy=(x_point, y_point), 
             xytext=(x_point-2500, y_point-30),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=12)

plt.grid()
plt.show()

# %% [markdown]
# ## Batch Plot

# %% [markdown]
# ### Seed independence

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import seaborn as sns
import os

plt.style.use('default')
folder = "output"
file = lambda i: "output_scenario_1_seed_{0}.csv".format(str(i))

# %%
l = []

for i in range(1, 101):
    data = pd.read_csv("/".join([folder, file(i)]))
    avg = data['order_number'].max()

    l.append(avg)

# %%
# Set the aesthetic style of the plots

# Create the plot
plt.figure(figsize=(6,4))
histplot = sns.histplot(l, bins=50, kde=True, color="blue", line_kws={"linewidth": 2})

# Customize the plot
plt.xlabel("Number of Order", fontsize=14, fontweight='bold')
plt.ylabel("Density", fontsize=14, fontweight='bold')
plt.title("Histogram of Average Waiting time with Fitted KDE", fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()
