# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd


d = pd.read_csv("output/output.csv")

# %%
d.describe()
# Out:
#          total_cons  standby_cons  ave_waiting_time       mileage  \
# count  43200.000000  43200.000000      43200.000000  43200.000000
# mean    4240.712961    165.366803       4251.738997   4766.852443
# std     2632.245224    105.330779       2367.369517   2893.736511
# min        0.000000      0.000000          0.000000      0.000000
# 25%     2062.488627     67.410989       2049.549797   2389.337248
# 50%     4095.183463    175.789768       4020.104336   4570.633103
# 75%     6437.222746    261.779761       6327.974631   7147.660362
# max     8983.397615    345.393400       8257.167842   9912.476141
#
#           mean_time  truck_in_depot_0  truck_in_depot_1  truck_in_depot_2  \
# count  43200.000000      43200.000000      43200.000000      43200.000000
# mean   21599.500000          0.180093          0.249653          0.161458
# std    12470.910151          0.668977          0.853088          0.695909
# min        0.000000          0.000000          0.000000          0.000000
# 25%    10799.750000          0.000000          0.000000          0.000000
# 50%    21599.500000          0.000000          0.000000          0.000000
# 75%    32399.250000          0.000000          0.000000          0.000000
# max    43199.000000          5.000000          5.000000          5.000000
#
#        truck_in_depot_3  carbon_emission  ...  truck_total_time_delivery  \
# count      43200.000000     43200.000000  ...               43200.000000
# mean           0.101505      1136.511074  ...              246550.390422
# std            0.607939       705.441720  ...              150736.370965
# min            0.000000         0.000000  ...                   0.000000
# 25%            0.000000       552.746952  ...              122073.099660
# 50%            0.000000      1097.509168  ...              237159.445909
# 75%            0.000000      1725.175696  ...              372732.907633
# max            5.000000      2407.550561  ...              514963.125659
#
#        time_window_truck_total_time_parking  \
# count                          43200.000000
# mean                            2521.775077
# std                             5780.222672
# min                                0.000000
# 25%                               40.010901
# 50%                               45.393537
# 75%                               92.266246
# max                            24475.954398
#
#        time_window_truck_total_time_queue  \
# count                        43200.000000
# mean                         15807.837238
# std                           7253.273282
# min                              0.000000
# 25%                          10675.100996
# 50%                          15893.416158
# 75%                          20485.026869
# max                          29981.508489
#
#        time_window_truck_total_time_service  \
# count                          43200.000000
# mean                            9571.511683
# std                             1940.098838
# min                                0.000000
# 25%                             9279.268174
# 50%                             9898.703343
# 75%                            10677.888556
# max                            13301.471022
#
#        time_window_truck_total_time_delivery  completed_order_num  \
# count                           43200.000000         43200.000000
# mean                            41098.042669          1118.897593
# std                             10727.055006           679.145095
# min                                 0.000000             0.000000
# 25%                             38740.464221           564.000000
# 50%                             42958.725611          1066.000000
# 75%                             47211.296480          1686.000000
# max                             54814.766049          2333.000000
#
#        unfinished_order_0  unfinished_order_1  unfinished_order_2  \
# count        43200.000000        43200.000000        43200.000000
# mean           130.222546          100.802245          103.011042
# std             82.826675           69.330163           77.522636
# min              0.000000            0.000000            0.000000
# 25%             45.000000           39.000000           27.000000
# 50%            150.000000          118.000000          105.000000
# 75%            204.000000          165.000000          165.000000
# max            251.000000          219.000000          248.000000
#
#        unfinished_order_3
# count        43200.000000
# mean           215.994051
# std             93.551334
# min              0.000000
# 25%            148.000000
# 50%            252.000000
# 75%            287.000000
# max            328.000000
#
# [8 rows x 29 columns]

# %%
d.columns
# Out:
# Index(['total_cons', 'standby_cons', 'ave_waiting_time', 'mileage',
#        'mean_time', 'truck_in_depot_0', 'truck_in_depot_1', 'truck_in_depot_2',
#        'truck_in_depot_3', 'carbon_emission', 'order_number', 'ave_queue_time',
#        'total_queue_length', 'service_cons', 'time_window_ave_queue_time',
#        'time_window_ave_waiting_time', 'truck_total_time_parking',
#        'truck_total_time_queue', 'truck_total_time_service',
#        'truck_total_time_delivery', 'time_window_truck_total_time_parking',
#        'time_window_truck_total_time_queue',
#        'time_window_truck_total_time_service',
#        'time_window_truck_total_time_delivery', 'completed_order_num',
#        'unfinished_order_0', 'unfinished_order_1', 'unfinished_order_2',
#        'unfinished_order_3'],
#       dtype='object')

# %%
d[['completed_order_num']].plot()
# Out:
# <Axes: >

# %%
d['time_window_truck_total_time_parking'].plot()
# Out:
# <Axes: >

# %%
d[['truck_in_depot_0', 'truck_in_depot_1', 'truck_in_depot_2', 'truck_in_depot_3']].plot()
# Out:
# <Axes: >
