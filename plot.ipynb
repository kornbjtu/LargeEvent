# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd


d = pd.read_csv("output.csv")

# %%
d.describe()
# Out:
#          total_cons  standby_cons  ave_waiting_time       mileage  \
# count  43200.000000  43200.000000      43200.000000  43200.000000
# mean    2387.705380    105.610624       8709.204578   2590.003956
# std     1456.947282     58.500886       4790.700831   1583.406665
# min        0.000000      0.000000          0.000000      0.000000
# 25%     1149.686794     51.130441       4706.235938   1252.786858
# 50%     2376.360787    110.753740       8891.616460   2564.982501
# 75%     3765.770740    145.109056      13029.906187   4059.084315
# max     4684.030135    212.296679      16624.301554   5211.973466
#
#           mean_time  truck_in_depot_0  truck_in_depot_1  truck_in_depot_2  \
# count  43200.000000      43200.000000      43200.000000      43200.000000
# mean   21599.500000          0.020648          0.033773          0.024907
# std    12470.910151          0.204782          0.286252          0.223050
# min        0.000000          0.000000          0.000000          0.000000
# 25%    10799.750000          0.000000          0.000000          0.000000
# 50%    21599.500000          0.000000          0.000000          0.000000
# 75%    32399.250000          0.000000          0.000000          0.000000
# max    43199.000000          3.000000          3.000000          3.000000
#
#        truck_in_depot_3  carbon_emission  ...  truck_total_time_service  \
# count      43200.000000     43200.000000  ...              43200.000000
# mean           0.025810       639.905042  ...              46505.485682
# std            0.230151       390.461871  ...              25328.134485
# min            0.000000         0.000000  ...                  0.000000
# 25%            0.000000       308.116061  ...              25314.986884
# 50%            0.000000       636.864691  ...              46760.166286
# 75%            0.000000      1009.226558  ...              67946.292030
# max            3.000000      1255.320076  ...              90452.028290
#
#        truck_total_time_delivery  time_window_truck_total_time_parking  \
# count               43200.000000                          43200.000000
# mean               154764.012754                          14447.859306
# std                 95320.992345                           5351.386671
# min                     0.000000                              0.000000
# 25%                 75176.118441                          11163.589406
# 50%                152458.623780                          14212.943697
# 75%                243562.177016                          17840.739371
# max                312746.763265                          28369.543768
#
#        time_window_truck_total_time_queue  \
# count                        43200.000000
# mean                          6557.304894
# std                           3756.445417
# min                              0.000000
# 25%                           3566.794918
# 50%                           5644.763557
# 75%                           8930.673088
# max                          17061.035140
#
#        time_window_truck_total_time_service  \
# count                          43200.000000
# mean                            5348.597464
# std                             1596.417952
# min                                0.000000
# 25%                             4433.149153
# 50%                             5457.911613
# 75%                             6543.209699
# max                             9740.027845
#
#        time_window_truck_total_time_delivery  unfinished_order_0  \
# count                           43200.000000        43200.000000
# mean                            15045.738336          686.245903
# std                              5743.895978          435.474312
# min                                 0.000000            0.000000
# 25%                             11284.744404          285.000000
# 50%                             14904.760038          686.000000
# 75%                             19673.211564         1076.000000
# max                             27647.147986         1442.000000
#
#        unfinished_order_1  unfinished_order_2  unfinished_order_3
# count        43200.000000        43200.000000        43200.000000
# mean           644.043819          696.218079          727.690208
# std            375.250625          391.689518          390.545669
# min              0.000000            0.000000            0.000000
# 25%            316.000000          355.000000          406.000000
# 50%            637.000000          732.000000          737.000000
# 75%            954.000000         1013.000000         1063.000000
# max           1313.000000         1360.000000         1382.000000
#
# [8 rows x 28 columns]

# %%
d.columns
# Out:
# Index(['total_cons', 'standby_cons', 'ave_waiting_time', 'mileage',
#        'mean_time', 'truck_in_depot_0', 'truck_in_depot_1', 'truck_in_depot_2',
#        'truck_in_depot_3', 'carbon_emission', 'order_number', 'ave_queue_time',
#        'total_queue_length', 'service_cons', 'time_window_ave_queue_time',
#        'time_window_ave_waiting_time', 'truck_total_time_parking',
#        'truck_total_time_queue', 'truck_total_time_service',
#        'truck_total_time_delivery', 'time_window_truck_total_time_parking',
#        'time_window_truck_total_time_queue',
#        'time_window_truck_total_time_service',
#        'time_window_truck_total_time_delivery', 'unfinished_order_0',
#        'unfinished_order_1', 'unfinished_order_2', 'unfinished_order_3'],
#       dtype='object')

# %%
d[["unfinished_order_0", "unfinished_order_1", "unfinished_order_2", "unfinished_order_3"]].plot()
# Out:
# <Axes: >

# %%
d['time_window_truck_total_time_parking'].plot()
# Out:
# <Axes: >

# %%
d[['truck_in_depot_0', 'truck_in_depot_1', 'truck_in_depot_2', 'truck_in_depot_3']].plot()
# Out:
# <Axes: >
